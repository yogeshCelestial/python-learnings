# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
marks = np.random.randint(0, 100, 100)

# %%
plt.hist(marks)
# Out:
# (array([ 9.,  8.,  7., 12., 11., 17., 14., 11.,  6.,  5.]),
#  array([ 0. ,  9.9, 19.8, 29.7, 39.6, 49.5, 59.4, 69.3, 79.2, 89.1, 99. ]),
#  <BarContainer object of 10 artists>)
