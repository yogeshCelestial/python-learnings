# %%
import pandas as pd

# %%
df = pd.read_csv('./assets/MOCK_DATA.csv')
df
# Out:
#     id first_name    last_name                               email  \
# 0    1     Yelena         Jess                    yjess0@zdnet.com
# 1    2      Deane     Patnelli            dpatnelli1@canalblog.com
# 2    3      Dixie          Kun                   dkun2@histats.com
# 3    4     Millie         Jest             mjest3@odnoklassniki.ru
# 4    5     Valeda       Hannen                vhannen4@cbsnews.com
# 5    6   Shepherd      Le land                 sleland5@tripod.com
# 6    7  Nathaniel       Carson              ncarson6@bloomberg.com
# 7    8    Bobette     Hubbocks              bhubbocks7@reuters.com
# 8    9    Wilfrid      Perutto          wperutto8@businessweek.com
# 9   10    Fredric        Fardy                   ffardy9@nymag.com
# 10  11   Caldwell      Marthen             cmarthena@blinklist.com
# 11  12      Willa     Goodlake              wgoodlakeb@squidoo.com
# 12  13  Guenevere       Fortie         gfortiec@simplemachines.org
# ...

# %%
df1 = df.replace('Gave', 'Yogesh')
df1
# Out:
#     id first_name    last_name                               email  \
# 0    1     Yelena         Jess                    yjess0@zdnet.com
# 1    2      Deane     Patnelli            dpatnelli1@canalblog.com
# 2    3      Dixie          Kun                   dkun2@histats.com
# 3    4     Millie         Jest             mjest3@odnoklassniki.ru
# 4    5     Valeda       Hannen                vhannen4@cbsnews.com
# 5    6   Shepherd      Le land                 sleland5@tripod.com
# 6    7  Nathaniel       Carson              ncarson6@bloomberg.com
# 7    8    Bobette     Hubbocks              bhubbocks7@reuters.com
# 8    9    Wilfrid      Perutto          wperutto8@businessweek.com
# 9   10    Fredric        Fardy                   ffardy9@nymag.com
# 10  11   Caldwell      Marthen             cmarthena@blinklist.com
# 11  12      Willa     Goodlake              wgoodlakeb@squidoo.com
# 12  13  Guenevere       Fortie         gfortiec@simplemachines.org
# ...

# %%
df2 = df.replace(to_replace=50, value=5000)
df2.tail()
# Out:
#       id first_name last_name                     email  gender
# 45    46     Worthy    Erangy        werangy19@admin.ch    Male
# 46    47     Jarrad      Gave  jgave1a@biblegateway.com    Male
# 47    48    Celeste      Idel          cidel1b@gmpg.org  Female
# 48    49    Georgie     Speir        gspeir1c@zdnet.com  Female
# 49  5000      Ilysa   Shannon  ishannon1d@bloomberg.com  Female

# %%
newDf = pd.read_csv('./assets/marks.csv')
newDf.head()
# Out:
#    roll_number  english  chemistry  math
# 0            1     28.0        NaN  63.0
# 1            2     17.0       64.0  78.0
# 2            3     63.0       29.0   NaN
# 3            4     35.0        5.0  59.0
# 4            5     57.0       33.0  18.0

# %%
newDf1 = newDf.replace(to_replace=[17, 50, 5, 28], value='new value') # value can be a string opr integer
newDf1
# Out:
#    roll_number    english  chemistry  math
# 0            1  new value        NaN  63.0
# 1            2  new value       64.0  78.0
# 2            3       63.0       29.0   NaN
# 3            4       35.0  new value  59.0
# 4    new value       57.0       33.0  18.0
# 5            6       80.0       90.0  95.0
# 6            7       42.0       83.0   NaN
# 7            8       33.0       92.0   7.0
# 8            9       42.0       72.0  58.0
# 9           10       42.0       47.0  76.0
# 10          11        NaN       54.0   2.0
# 11          12       41.0       83.0  41.0
# 12          13       64.0       45.0  72.0
# 13          14       57.0       36.0  78.0
# 14          15       49.0       30.0  93.0
# 15          16       39.0       81.0  82.0
# 16   new value       55.0        NaN  84.0
# 17          18       72.0       51.0  59.0
# 18          19       42.0       12.0  15.0
# 19          20       25.0        7.0  89.0
# 20          21  new value       95.0  43.0
# ...

# %%
newDf2 = newDf1.replace('[A-Za-z]', 90000, regex=True)
newDf2
# Out:
# C:\Users\yogesh\AppData\Local\Temp\ipykernel_1524\3309022414.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   newDf2 = newDf1.replace('[A-Za-z]', 90000, regex=True)
#     roll_number  english  chemistry  math
# 0             1  90000.0        NaN  63.0
# 1             2  90000.0       64.0  78.0
# 2             3     63.0       29.0   NaN
# 3             4     35.0    90000.0  59.0
# 4         90000     57.0       33.0  18.0
# 5             6     80.0       90.0  95.0
# 6             7     42.0       83.0   NaN
# 7             8     33.0       92.0   7.0
# 8             9     42.0       72.0  58.0
# 9            10     42.0       47.0  76.0
# 10           11      NaN       54.0   2.0
# 11           12     41.0       83.0  41.0
# ...
